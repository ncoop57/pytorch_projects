# %%
# Author: Robert Guthrie

import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
word_to_idx = {"hello": 0, "world": 1}
embeds = nn.Embedding(2, 20)
lookup_tensor = torch.LongTensor([word_to_idx["hello"]])
hello_embed = embeds(autograd.Variable(lookup_tensor))
print(hello_embed)
# Out:
# Variable containing:
#
# Columns 0 to 9
# -0.4028  1.1829  0.9835  0.3636  0.0657  1.1428  0.5317  0.9533  1.3423 -0.8362
#
# Columns 10 to 19
# -1.0735  1.7191 -0.0419 -1.2742 -1.1563 -0.1100 -1.0819  0.1948  1.6725 -1.2586
# [torch.FloatTensor of size 1x20]

# %%
# Setting up word indices
CONTEXT_SIZE = 2
EMBEDDING_DIM = 10

# We will use Shakespeare Sonnet 2
test_sentence = """When forty winters shall besiege thy brow,
And dig deep trenches in thy beauty's field,
Thy youth's proud livery so gazed on now,
Will be a totter'd weed of small worth held:
Then being asked, where all thy beauty lies,
Where all the treasure of thy lusty days;
To say, within thine own deep sunken eyes,
Were an all-eating shame, and thriftless praise.
How much more praise deserv'd thy beauty's use,
If thou couldst answer 'This fair child of mine
Shall sum my count, and make my old excuse,'
Proving his beauty by succession thine!
This were to be new made when thou art old,
And see thy blood warm when thou feel'st it cold.""".split()

trigrams = [([test_sentence[i], test_sentence[i + 1]], test_sentence[i + 2])
            for i in range(len(test_sentence) - 2)]

print(trigrams[:3])

vocab = set(test_sentence)
word_to_idx = {word: i for i, word in enumerate(vocab)}
# Out:
# [(['When', 'forty'], 'winters'), (['forty', 'winters'], 'shall'), (['winters', 'shall'], 'besiege')]

# %%
# Defining the n-gram model

class NGramLanguageModeler(nn.Module):
    
    def __init__(self, vocab_size, embedding_dim, context_size):
        super(NGramLanguageModeler, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.l1 = nn.Linear(context_size * embedding_dim, 128)
        self.l2 = nn.Linear(128, vocab_size)
        
    def forward(self, inputs):
        embeds = self.embeddings(inputs).view((1, -1))
        out = F.relu(self.l1(embeds))
        out = self.l2(out)
        log_probs = F.log_softmax(out, dim = 1)
        return log_probs

# %%
# Define the loss and optimizer
losses = []
loss_fn = nn.NLLLoss()
model = NGramLanguageModeler(len(vocab), EMBEDDING_DIM, CONTEXT_SIZE)
optimizer = optim.SGD(model.parameters(), lr = 1e-3)

# %%
# Train the model
for epoch in range(100):
    total_loss = torch.Tensor([0])
    for context, target in trigrams:
        context_idxs = [word_to_idx[w] for w in context]
        context_var = autograd.Variable(torch.LongTensor(context_idxs))
        
        model.zero_grad()
        
        log_probs = model(context_var)
        loss = loss_fn(log_probs, autograd.Variable(torch.LongTensor([word_to_idx[target]])))
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.data
    losses.append(total_loss)
    
print(losses)
# Out:
# [
#  523.7093
# [torch.FloatTensor of size 1]
# ,
#  521.5616
# [torch.FloatTensor of size 1]
# ,
#  519.4286
# [torch.FloatTensor of size 1]
# ,
#  517.3098
# [torch.FloatTensor of size 1]
# ,
#  515.2038
# [torch.FloatTensor of size 1]
# ,
#  513.1116
# [torch.FloatTensor of size 1]
# ,
#  511.0313
# [torch.FloatTensor of size 1]
# ,
#  508.9619
# [torch.FloatTensor of size 1]
# ,
#  506.9032
# [torch.FloatTensor of size 1]
# ,
#  504.8552
# [torch.FloatTensor of size 1]
# ,
#  502.8157
# [torch.FloatTensor of size 1]
# ,
#  500.7852
# [torch.FloatTensor of size 1]
# ,
#  498.7622
# [torch.FloatTensor of size 1]
# ,
#  496.7465
# [torch.FloatTensor of size 1]
# ,
#  494.7358
# [torch.FloatTensor of size 1]
# ,
#  492.7322
# [torch.FloatTensor of size 1]
# ,
#  490.7321
# [torch.FloatTensor of size 1]
# ,
#  488.7357
# [torch.FloatTensor of size 1]
# ,
#  486.7437
# [torch.FloatTensor of size 1]
# ,
#  484.7559
# [torch.FloatTensor of size 1]
# ,
#  482.7704
# [torch.FloatTensor of size 1]
# ,
#  480.7882
# [torch.FloatTensor of size 1]
# ,
#  478.8091
# [torch.FloatTensor of size 1]
# ,
#  476.8319
# [torch.FloatTensor of size 1]
# ,
#  474.8562
# [torch.FloatTensor of size 1]
# ,
#  472.8824
# [torch.FloatTensor of size 1]
# ,
#  470.9090
# [torch.FloatTensor of size 1]
# ,
#  468.9355
# [torch.FloatTensor of size 1]
# ,
#  466.9634
# [torch.FloatTensor of size 1]
# ,
#  464.9921
# [torch.FloatTensor of size 1]
# ,
#  463.0214
# [torch.FloatTensor of size 1]
# ,
#  461.0487
# [torch.FloatTensor of size 1]
# ,
#  459.0772
# [torch.FloatTensor of size 1]
# ,
#  457.1041
# [torch.FloatTensor of size 1]
# ,
#  455.1305
# [torch.FloatTensor of size 1]
# ,
#  453.1545
# [torch.FloatTensor of size 1]
# ,
#  451.1773
# [torch.FloatTensor of size 1]
# ,
#  449.1968
# [torch.FloatTensor of size 1]
# ,
#  447.2140
# [torch.FloatTensor of size 1]
# ,
#  445.2260
# [torch.FloatTensor of size 1]
# ,
#  443.2347
# [torch.FloatTensor of size 1]
# ,
#  441.2411
# [torch.FloatTensor of size 1]
# ,
#  439.2422
# [torch.FloatTensor of size 1]
# ,
#  437.2410
# [torch.FloatTensor of size 1]
# ,
#  435.2361
# [torch.FloatTensor of size 1]
# ,
#  433.2263
# [torch.FloatTensor of size 1]
# ,
#  431.2122
# [torch.FloatTensor of size 1]
# ,
#  429.1928
# [torch.FloatTensor of size 1]
# ,
#  427.1668
# [torch.FloatTensor of size 1]
# ,
#  425.1343
# [torch.FloatTensor of size 1]
# ,
#  423.0955
# [torch.FloatTensor of size 1]
# ,
#  421.0508
# [torch.FloatTensor of size 1]
# ,
#  418.9994
# [torch.FloatTensor of size 1]
# ,
#  416.9419
# [torch.FloatTensor of size 1]
# ,
#  414.8772
# [torch.FloatTensor of size 1]
# ,
#  412.8049
# [torch.FloatTensor of size 1]
# ,
#  410.7263
# [torch.FloatTensor of size 1]
# ,
#  408.6401
# [torch.FloatTensor of size 1]
# ,
#  406.5477
# [torch.FloatTensor of size 1]
# ,
#  404.4468
# [torch.FloatTensor of size 1]
# ,
#  402.3369
# [torch.FloatTensor of size 1]
# ,
#  400.2182
# [torch.FloatTensor of size 1]
# ,
#  398.0924
# [torch.FloatTensor of size 1]
# ,
#  395.9565
# [torch.FloatTensor of size 1]
# ,
#  393.8115
# [torch.FloatTensor of size 1]
# ,
#  391.6569
# [torch.FloatTensor of size 1]
# ,
#  389.4911
# [torch.FloatTensor of size 1]
# ,
#  387.3157
# [torch.FloatTensor of size 1]
# ,
#  385.1302
# [torch.FloatTensor of size 1]
# ,
#  382.9348
# [torch.FloatTensor of size 1]
# ,
#  380.7296
# [torch.FloatTensor of size 1]
# ,
#  378.5135
# [torch.FloatTensor of size 1]
# ,
#  376.2889
# [torch.FloatTensor of size 1]
# ,
#  374.0542
# [torch.FloatTensor of size 1]
# ,
#  371.8105
# [torch.FloatTensor of size 1]
# ,
#  369.5562
# [torch.FloatTensor of size 1]
# ,
#  367.2925
# [torch.FloatTensor of size 1]
# ,
#  365.0179
# [torch.FloatTensor of size 1]
# ,
#  362.7334
# [torch.FloatTensor of size 1]
# ,
#  360.4388
# [torch.FloatTensor of size 1]
# ,
#  358.1342
# [torch.FloatTensor of size 1]
# ,
#  355.8223
# [torch.FloatTensor of size 1]
# ,
#  353.4997
# [torch.FloatTensor of size 1]
# ,
#  351.1670
# [torch.FloatTensor of size 1]
# ,
#  348.8248
# [torch.FloatTensor of size 1]
# ,
#  346.4759
# [torch.FloatTensor of size 1]
# ,
#  344.1143
# [torch.FloatTensor of size 1]
# ,
#  341.7466
# [torch.FloatTensor of size 1]
# ,
#  339.3683
# [torch.FloatTensor of size 1]
# ,
#  336.9814
# [torch.FloatTensor of size 1]
# ,
#  334.5847
# [torch.FloatTensor of size 1]
# ,
#  332.1805
# [torch.FloatTensor of size 1]
# ,
#  329.7674
# [torch.FloatTensor of size 1]
# ,
#  327.3451
# [torch.FloatTensor of size 1]
# ,
#  324.9183
# [torch.FloatTensor of size 1]
# ,
#  322.4815
# [torch.FloatTensor of size 1]
# ,
#  320.0392
# [torch.FloatTensor of size 1]
# ,
#  317.5891
# [torch.FloatTensor of size 1]
# ,
#  315.1299
# [torch.FloatTensor of size 1]
# ,
#  312.6651
# [torch.FloatTensor of size 1]
# ,
#  310.1947
# [torch.FloatTensor of size 1]
# ,
#  307.7171
# [torch.FloatTensor of size 1]
# ,
#  305.2352
# [torch.FloatTensor of size 1]
# ,
#  302.7479
# [torch.FloatTensor of size 1]
# ,
#  300.2567
# [torch.FloatTensor of size 1]
# ,
#  297.7629
# [torch.FloatTensor of size 1]
# ,
#  295.2630
# [torch.FloatTensor of size 1]
# ,
#  292.7622
# [torch.FloatTensor of size 1]
# ,
#  290.2552
# [torch.FloatTensor of size 1]
# ,
#  287.7458
# [torch.FloatTensor of size 1]
# ]

# %%
# Testing model
context = ['When', 'forty']
context_idxs = [word_to_idx[w] for w in context]
context_var = autograd.Variable(torch.LongTensor(context_idxs))
log_probs = model(context_var)

values, indices = log_probs.max(0)
print(values)
print(indices)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-b7bf5c8bb2f1> in <module>()
#       5 log_probs = model(context_var)
#       6
# ----> 7 values, indices = log_probs.max()
#       8 print(values)
#       9 print(indices)
#
# ValueError: not enough values to unpack (expected 2, got 1)
